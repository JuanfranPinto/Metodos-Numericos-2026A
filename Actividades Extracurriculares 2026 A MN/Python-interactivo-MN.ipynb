# %% [markdown]
# #### Pinto Andrango Juan Francisco
# #### Actividad Extra 05
# #### Python Interactivo
# #### 02/50/2026

# %% [markdown]
# ### Link del repositorio de Git-Hub
# https://github.com/JuanfranPinto/Metodos-Numericos-2026A/blob/main/Actividades%20Extracurriculares%202026%20A%20MN/Python-interactivo-MN.ipynb

# %% [markdown]
# #### Curso de mas de 8 horas
# ![image.png](attachment:image.png)

# %% [markdown]
# ### CURSO DE PYTHON DE CISCO NETWORKING ACADEMY

# %% [markdown]
# ### Modulo 1
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Modulo 2
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Modulo 3
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Modulo 4
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Certifica del curso
# ![image.png](attachment:image.png)
