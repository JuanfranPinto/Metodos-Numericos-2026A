# %% [markdown]
# #### Pinto Andrango Juan Francisco
# #### Actividad Extracurricular N 5
# #### Python Interactivo
# #### 02/50/2026

# %% [markdown]
# #### Link del Repositorio de Git-hub
#
# https://github.com/JuanfranPinto/Metodos-Numericos-2026A/blob/main/Actividades%20Extracurriculares%202026%20A%20MN/Cetificado-De-Cisco-Python-MN.ipynb

# %% [markdown]
# #### Link del Certifica de Python
# https://epnecuador-my.sharepoint.com/:f:/g/personal/juan_pinto_epn_edu_ec/IgCA3TxG6EScQJ_GamVkP2jKAYmSmk7fLT96_VnR56pwP4o?e=iLSYqe

# %% [markdown]
# #### Certificado de Python
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### El curso se dasarrollo con modulos interactivos
# ![image.png](attachment:image.png)

# %% [markdown]
# #### modulo 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Modulo 3
# ![image.png](attachment:image.png)

# %% [markdown]
# ####  Modulo 4 Final
# ![image.png](attachment:image.png)
