# %% [markdown]
# #### Pinto Andrango Juan Francisco
# #### Actividad Extracurricular 2B
# #### Ajuste de Curvas
# #### 08/07/2026

# %% [markdown]
# #### Link del Repositorio de Git-hub
#
# https://github.com/JuanfranPinto/Metodos-Numericos-2026A/blob/main/Actividades%20Extracurriculares%202026%20A%20MN/Ajuste-de-curvas-double-descent-MN.ipynb

# %% [markdown]
# ## What the Books Get Wrong about AI  Double Descent
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Double Descent
#
# el video expone la importancion de la enseñanza de las inteligencias artificaicles que se la conoce como Double Descent
# el punto de partida trata que la enseñanza al autmar la complejidad de un modelor el error de prueba puedes disminuir hasta cierto punto en una grafico tipo U
# y luego comienza a umentar por el overfittign.  Con las inteligencias artificales modernas como las redes nueronales profundas se aprecia que al ser muy grandes
# y capaces de memorizar los datos de entrenamiento.
#
# las investigaciones descubrieron que al aumento de tamañano del modelo, el erro en los conjuntos de prueba empieza a descender. Un punto critico donde el modelo
# tiene mayor dificultad es en la interpolacion de todos los datos pero aun no tiene la flexibilidad suficiente para encontrar soluciones suaves.
#
# el double descent muestra que la relacion entre la complejidad del modelo y el erros es complejo mas que en los libros de investigacion. esto debido a que las inteligencias artificales avanzan mas rapido de la comprension teorica.
