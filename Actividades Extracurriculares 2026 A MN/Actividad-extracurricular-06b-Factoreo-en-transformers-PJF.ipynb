# %% [markdown]
# #### Metodos Numericos  2026 A
# #### Pinto Andrango Juan Francisco
# #### Actividad Extra 06B
# #### Factoreo en Transformers
# #### 19/07/2026

# %% [markdown]
# ## Link el Repositorio ded Git-Hub

# %% [markdown]
# ### Investigue sobre el uso de factoreo de matrices en la arquitectura de redes neuronales Transformers.
# ### Indique las razones y las ventajas de realizar esta operación.
#
# ### Investigar su uso en la técnica LORA y Lower value decomposition.
# ### Compararlo con los temas visto en clase.

# %% [markdown]
# ## Factoreo en transformers
#
# Investigue sobre el uso de factoreo de matrices en la arquitectura de redes neuronales Transformers.
# Indique las razones y las ventajas de realizar esta operación.

# %% [markdown]
# #### Redes Neuronales en modelos de lenguaje
#
# Una red neuronal es el método de la inteligencia artificial que se encarga de enseñar a las computadoras cómo procesar datos de manera similar a la del cerebro humano. Es un proceso de Machine Learning que se denomina aprendizaje profundo, que utiliza los nodos o las neuronas interconectadas en una estructura de estilo capas. Se crea un sistema adaptable que las computadoras utilizan para aprender de errores y realizar una mejora continua. Así, las redes neuronales artificiales intentan resolver problemas complejos como resúmenes de documentos o reconocimiento de rostros, todo esto con mayor precisión

# %% [markdown]
# #### Redes Transformer
#
# Las Redes Transformer son un nuevo tipo de red neuronal que planea transformarse en un gran avance para el Machine Learning. La red Transformer nació como una alternativa al problema de la traducción de texto de un idioma a otro. En estas redes, la totalidad de la secuencia de entrada se procesa en paralelo por la red. La nueva secuencia es convertida en representación numérica usando un embedding.
#
# Una red de tipo Transformer es solo una red neuronal para secuencias que se basa en autoatención, que se adapta al texto. En la actualidad se impulsan avances en el procesamiento de lenguaje natural y esta es su arquitectura.
#
# ![image.png](attachment:image.png)
#
# #### Attention is all you need
#
# *La Red Transformer descrita en el artículo de 2017 , desarrollado por investigadores de Google, y nacieron inicialmente como una alternativa al problema de la traducción de texto de un idioma a otro.*
#
# Los Transformers son una arquitectura de red neuronal desarrollada para tareas de procesamiento de lenguaje, que se ha consolidado como herramienta principal para abordar problemas como el procesamiento de texto, audio, imágenes, aprendizaje y otros dominios de datos. Su aspecto destacado es el mecanismo de autoatención, que hace que el modelo pondere dinámicamente diferentes partes de una secuencia de entrada al procesarla.

# %% [markdown]
# ### Factoreo de matrices en la arquitectura de redes neuronales Transformers
#
# El factoreo de matrices en las redes neuronales Transformers no forma parte de un proceso que hace una red de manera natural. Es una nueva técnica de optimización inteligente usada principalmente en los modelos de lenguaje gigantes, como GPT o Llama, para que trabajen de manera más rápida o para poder reentrenarlos (fine-tuning) sin la necesidad de una supercomputadora.
#
# Una red Transformer tiene parámetros ("pesos") que son matrices gigantescas de números. El factoreo de matrices trata de representar una tabla gigante como la multiplicación de dos matrices más pequeñas. El factoreo de matrices es una técnica de compresión y eficiencia que permite a los modelos de lenguaje poder ser más manejables, rápidos y entrenables.

# %% [markdown]
# ## Técnica LORA y Lower value decomposition.

# %% [markdown]
# ### Tecnica LORA
#
# #### *Low-Rank Adaptation of Large Language Models*
#
# LoRA,  congela los pesos del modelo previamente entrenados e inyecta matrices de descomposición de rango entrenables en cada capa de la arquitectura del Transformador, reduciendo significativamente la cantidad de parámetros entrenables para tareas posteriores. En comparación con GPT-3 LoRA puede reducir la cantidad de parámetros entrenables en un factor de 10,000 y el requisito de memoria de la GPU en un factor de 3. LoRA ajusta la calidad del modelo en RoBERTa, DeBERTa. al tener menos parámetros entrenables un mayor rendimiento de entrenamiento y, a diferencia de los adaptadores, ninguna latencia de inferencia adicional.
#
# #### Funcionamiento de LORA
#
# A partir del ajuste fino (fine-Tuning) los cambios que requiere necesitan un trasformer son de un rango muy bajo. lo que significa que el modelo no requiere modificar millones de parametros si no que ahora solo requiere de pequeños ajustes que se representan mediante matries pequeñas
#
# #### Ventajas de LORA
#
# Redeccoin en la memoria de entrenamiento respeccto al ajuste completo dependiendo del modelo y rango elegido, menos parametros debido a que usa una pequeña fraccion cuenta con un entrenamiento rapido menos operaciones, memoria, menor tiempo.

# %% [markdown]
# ### Singular Value Decomposition (SVD)
#
# la descomposicion en Valores Singulares es un tecnica de algebra lineal que permite descomponer cualquier matriz en 3 matrices mas simples, por lo general se la usa en la reduccion de dimensionalidad, la comprension de datos y el analisis de la informacion. los valores singulares indican la importancia de cada componente de la informacion que esta en la matriz.
#
# - Valores singulares grandes: contienen la mayor parte de la información.
# - Valores singulares pequeños: aportan muy poca información y, en muchos casos, pueden eliminarse sin afectar significativamente el resultado.
#
# ### Ventajas de SVD
#
# Reduce el almacenamiento, disminuye el costo computacional, elimina información redundante, facilita la compresión de modelos y matrices, permite aproximaciones eficientes de matrices muy grandes.
#
# ### Aplicaciones de la SVD
#
#
# Compresión de imágenes, procesamiento de señales, sistemas de recomendación, reconocimiento facial, procesamiento del lenguaje natural, reducción de dimensionalidad, compresión y optimización de redes neuronales profundas, ajuste eficiente de modelos Transformer.
#
# La Singular Value Decomposition (SVD) constituye la base matemática de diferentes técnicas modernas de compresión y optimización de modelos de inteligencia artificial. Su capacidad para representar matrices mediante aproximaciones de bajo rango permite reducir significativamente el número de parámetros y el costo computacional, manteniendo la mayor parte de la información original. Este principio es imporantante sobre el que se desarrollan métodos como LoRA, ampliamente utilizados para adaptar grandes modelos Transformer de forma eficiente.
