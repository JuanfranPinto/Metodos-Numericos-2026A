# %% [markdown]
# #### Pinto Andrango Juan Francisco
# #### Tarea 01 Metodos Numericos 2026A
# #### Curso de Python
# #### 02/50/2026

# %% [markdown]
# #### Link del Repositorio de Git-Huh

# %% [markdown]
# #### link del video
# https://www.youtube.com/watch?v=Bsv_07Q-D70&list=WL&index=15&t=3616s

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### temario que se vieron en el curso
#
# ##### primera hora Fundamentos Basicos
#
#
# Introducción a Pytho que es y cómo instalarlo,Variables y Objetos: Cómo almacenar datos en memoria.
# Tipos de datos básicos numeros enteros (int), decimales (float), complejos y cómo convertir entre ellos.
# Cadenas de texto (Strings): Creación de texto y uso de comillas.
#
# ##### Segunda hora Estructuras y Operadores
#
#
# Manipulación de Strings: Cómo cortar, separar y unir textos.Listas como almacenar elementos en un orden específico y la diferencia entre lo que se puede modificar.Operadores: Sumas, restas, comparaciones lógicas (and, or, not) y de identidad (is, in).
#
# #### Tercera hora Matemáticas y Condiciones
#
# Jerarquía de operaciones el orden en que la computadora resuelve las matemáticas.El módulo math: Uso de funciones matemáticas avanzadas (pi, raíces cuadradas, logaritmos, trigonometría).Condicionales (if, elif, else): Cómo hacer que el programa tome decisiones lógicas basadas en condiciones.
#
# #### Cuarta hora ciclos, Archivos e Introducción a Objetos
#
# Bucles uso de while  y fo, manejo de archivos: Cómo abrir, leer y guardar información en archivos de texto y manipular imágenes básicas.
# Programación Orientada a Objetos Los cimientos para crear tus propios objetos usando Clases, Instancias y la palabra clave self.
#
# #### Quinta Hora POO Avanzada y Manejo de Errores
#
#
# Herencia como una clase hereda propiedades de otra y Polimorfismo. Manejo de Excepciones: Cómo evitar que tu programa "colapse"
#
# ### Sexta hora Funciones Modulares y Ejercicios
#
# Funciones (def), Cómo empaquetar código para reutilizarlo, uso de argumentos y la diferencia entre variables locales y globales.Funciones Lambda: Funciones anónimas de una sola línea para tareas rápidas.
# Resolución de problemas usando código (ej. contador de palabras y distancias matemáticas).
#
# #### Septima hora Módulos, Generadores y Regex
#
# Módulos y Paquetes: Cómo organizar proyectos grandes importando archivos y librerías externas. Formas eficientes de procesar grandes cantidades de datos sin saturar la memoria.Comprensión de Listas Una forma  crear listas en una sola línea de código.
# Expresiones Regulares Búsqueda de patrones de texto complejos.
#
# #### Octava Hora Programación Funcional y Estructuras Abstractas
#
# como guardar objetos de Python en archivos para usarlos después.Programación Funcional: Uso de funciones avanzadas como Decoradores, map (aplicar una función a toda una lista), filter (filtrar datos) y reduce.
# Estructuras de datos abstractas: Creación y funcionamiento de las "Pilas" (Stacks), donde el último elemento en entrar es el primero en salir (como la función "Deshacer" de tu computadora).
