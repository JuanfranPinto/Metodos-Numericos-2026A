# %% [markdown]
# ### Secciones de un informe
#  *  **_ABSTRAC_** :Resumen
#  * **introducttion**: relevantess, objetivo
#  (encontrar un algritmo, comprobar experimentalmente).
#  * **Marco teorico**: conceptos y teorias
#  existentes. (problema del viajero).
#   * **Metodolgia**:  descripcion de lo que se hizo.
#   informacion suficiente para replicar el experimeto
#   -
#
#   lo que se hizo
#    - programacion en python, con estas herramientas.
#    - enunciar ideas descartradas o alternativas ingnoradas
#    - implementamos estos dos algoritmos  A,
#    B, planeacion de los experimentos.
#    - Hadware Utilizado.
#
#    **Resultados**
#    - resumen de las pruebas, variante y resultados obtenidos.
#    - se probo algoritmo A con configuracion  1a, 2a , 3a
#    - se probo algortimo B con
#    configuracion 1b , 2b , 3b
#
#    **Conclusiones**
#    - resumen de los hallazgos, implicaciones y posibles
#    directivas futuras.
#
#    **Recomendaciones**
#    Sugerencias para el futuro
#    - se recomeinda estudar mas para mejora la nota del proximo informe
#    - se recomienda haecer los debeeres por un mismo para aprender mejor
#    - se recomeinda hacer el tallaer sin ayuda de chat gtp
#    -

# %% [markdown]
# en la metodologia
